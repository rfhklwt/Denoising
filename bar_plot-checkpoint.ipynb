# %%
using DataFrames
using CSV
using Plots
using Images
using StatsPlots

# %%
key = "head"

folder_path = joinpath(@__DIR__, "export", key)
data_480_640 = CSV.read(joinpath(folder_path, "export_data.csv"), DataFrame)

sx = repeat(["RSE", "SDM"], inner = 3)
nam = repeat(["240×320", "360×480", "480×640"], outer = 2)

data = filter(x -> x.Method == "sdm_data_zoom" || x.Method == "rse_data_zoom", data_480_640)
# Out:
# 6×8 DataFrame
#  Row │ Method         Dims     S      Dx     Dy     SSI       SMPI      ENL    ⋯
#      │ String         String   Int64  Int64  Int64  Float64   Float64   Float6 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ rse_data_zoom  240_320     70     80    140  0.65859   0.582469  0.9579 ⋯
#    2 │ rse_data_zoom  360_480     70    130     60  0.683841  0.589787  0.8884
#    3 │ rse_data_zoom  480_640     70     50    100  0.722435  0.622389  0.7960
#    4 │ sdm_data_zoom  240_320     70     80    140  0.744137  0.809172  0.7503
#    5 │ sdm_data_zoom  360_480     70    130     60  0.775741  0.812317  0.6904 ⋯
#    6 │ sdm_data_zoom  480_640     70     50    100  0.810592  0.835592  0.6323
#                                                                 1 column omitted

# %%
theme(:ggplot2)
pgfplotsx()
# Out:
# Plots.PGFPlotsXBackend()

# %% [markdown]
# ## Find the color you want to use

# %%
using ColorSchemes
using Colors
# Out:
# ArgumentError: Package ColorSchemes not found in current path:
# - Run `import Pkg; Pkg.add("ColorSchemes")` to install the ColorSchemes package.
#
#
# Stacktrace:
#  [1] require(into::Module, mod::Symbol)
#    @ Base ./loading.jl:867
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1090

# %%
ColorSchemes.rainbow
# Out:
# ColorScheme{StaticArrays.SArray{Tuple{17},RGB{Float64},1,17},String,String}(RGB{Float64}[RGB{Float64}(0.471412,0.108766,0.527016), RGB{Float64}(0.31106,0.11758,0.664469), RGB{Float64}(0.250728,0.225386,0.769152), RGB{Float64}(0.24408,0.361242,0.816084), RGB{Float64}(0.266122,0.486664,0.802529), RGB{Float64}(0.305919,0.585575,0.739666), RGB{Float64}(0.36048,0.655759,0.645692), RGB{Float64}(0.429842,0.701849,0.540321), RGB{Float64}(0.513417,0.72992,0.440682), RGB{Float64}(0.607651,0.743718,0.358588), RGB{Float64}(0.705038,0.742591,0.299167), RGB{Float64}(0.794549,0.721158,0.260829), RGB{Float64}(0.863512,0.670771,0.236564), RGB{Float64}(0.901014,0.582826,0.216542), RGB{Float64}(0.902853,0.453964,0.192014), RGB{Float64}(0.878107,0.293208,0.160481), RGB{Float64}(0.857359,0.131106,0.132128)], "general", "")

# %%
#color = [ColorSchemes.rainbow[2], ColorSchemes.rainbow[6]]

# %%
cgradients()
# Out:
# UndefVarError: cgradients not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[28]:1
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1090

# %%
color = [cgrad(:pu_or)[1], cgrad(:pu_or)[3]]
# Out:
# 2-element Array{RGBA{Float64},1} with eltype RGBA{Float64}:
#  RGBA{Float64}(0.17647058823529413,0.0,0.29411764705882354,1.0)
#  RGBA{Float64}(0.5019607843137255,0.45098039215686275,0.6745098039215687,1.0)

# %% [markdown]
# ## Ploting

# %%
p_ENL = groupedbar(nam, data.ENL, group = sx, ylabel = "ENL",
    fillalpha = 0.75, legend = false,
    bar_width = 0.67, lw = 0, tex_output_standalone = true)

p_SSI = groupedbar(nam, data.SSI, group = sx, ylabel = "SSI",
    fillalpha = 0.75, legend = false,
    bar_width = 0.67, lw = 0, tex_output_standalone = true)

p_SMPI = groupedbar(nam, data.SMPI, group = sx, ylabel = "SMPI",
    fillalpha = 0.75,
    bar_width = 0.67, lw = 0, tex_output_standalone = true)

# %%
p = plot(p_ENL, p_SSI, p_SMPI, layout=(1, 3), size=(900, 300), tex_output_standalone = true)

# %%
saving_path = joinpath(@__DIR__, "Plot")
savefig(p, joinpath(saving_path, "Bar_$key.tex"))

# %% [markdown]
# ## 论文第五章的`bar plot`

# %%
key = "head"

folder_path = joinpath(@__DIR__, "export", key)
data_480_640 = CSV.read(joinpath(folder_path, "export_data.csv"), DataFrame)

sx = repeat(["SSI", "SMPI", "ENL", "Time"], inner = 3)
nam = repeat(["LDR", "RSE", "SDM"], outer = 4)

data = filter(x -> x.Dims == "480_640" && occursin("zoom", x.Method), data_480_640)
# Out:
# 3×8 DataFrame
#  Row │ Method         Dims     S      Dx     Dy     SSI       SMPI      ENL    ⋯
#      │ String         String   Int64  Int64  Int64  Float64   Float64   Float6 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ ldr_data_zoom  480_640     70     50    100  0.776189  0.780943  0.6896 ⋯
#    2 │ rse_data_zoom  480_640     70     50    100  0.722435  0.622389  0.7960
#    3 │ sdm_data_zoom  480_640     70     50    100  0.810592  0.835592  0.6323
#                                                                 1 column omitted

# %%
if key == "tail"
    y = [data.SSI; data.SMPI; data.ENL; 0.473; 1.867; 1.290]
else
    y = [data.SSI; data.SMPI; data.ENL; 0.477; 1.878; 1.291]
end
# Out:
# 12-element Vector{Float64}:
#  0.7761891462369882
#  0.7224351563229309
#  0.810592190174469
#  0.780942822533655
#  0.6223885893019083
#  0.8355919936365371
#  0.6896459187455989
#  0.7960925453245186
#  0.632348468786184
#  0.477
#  1.878
#  1.291

# %%
p1 = groupedbar(nam, y, group = sx, ylabel = "Compare",
    fillalpha = 0.75,
    bar_width = 0.67, lw = 0, tex_output_standalone = true)

# %%
saving_path = joinpath(@__DIR__, "Plot")
savefig(p1, joinpath(saving_path, "Chp5_Bar_$key.tex"))
